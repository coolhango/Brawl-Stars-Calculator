# %%
# Hello! Click on the 'Run' button, then pull up the console window to fit your liking.
import math
import datetime

today = datetime.date.today()


def flaws():
    print("""
    _________________________________________________________________________________________________
    Unfortunately, the world isn't nothing but candy(sorry Mandy).
    Here are all the reasons why my algorithm can be inaccurate.
    
    1.Hidden Assumptions
    * The player has all game modes unlocked(+map maker)
    * Duels isn't permanent
    * Rewards of the pass(free & pay) will be the same as season 16
    * Believes every day of the week is the same => less reliable when it predicts you'll get the brawler <7 days.
    * No mid-way brawl pass purchase(quite common for F2P)
    * Optimal token collecting by player
    * Believes the new season quests will be done within the same week you received them
    * All other season quests are done
    * 500 token quests and 250 token quests show 50%/50% (I ain't sure)
    * Believes you'll get the brawler next season at most 
    
    These can often be solved by asking for more inputs, but will need more code.
    
    2.Out of One's Control
    * JACKPOT!
    * Challenges / Surprise quests
    * Trophy road rewards
    * Higher ranks/experience (additional tokens)
    * Double token events 
    * Player pays money
    
    I can't do much about these, and they affect results A LOT. 
    I suggest collecting all these extra rewards first before using my code.
    If you know these rewards are coming soon, just know it won't be as precise.
    
    3. A Thing
    * 1 day will be written as 1 days
    
    I just don't care about it XD 
    
    
    Plenty of flaws! So don't believe in the algorithm too much. 
    A single credit can be the difference of getting your brawler at tier 43 and tier 49.
    
    This is mainly for people unlocking high rarity brawlers, and will unlock their brawler between 7~60 days.
    If it takes more than 60 days, just focus on having fun now.
    Less than 7 days, and soon he'll/she'll/robot'll/animal'll/alien'll be yours.
    
    Although not pretty, these flaws are why I highly recommend using the "show math" action once, as it shows
    every step of the process, and shows why you should/shouldn't trust it.  
    """)


def first_look_page():
    print("""
    What now?
    
    show math: 
        Here lies all the math behind your result.
        Step by step, unique for every user.
        Readable but not pretty.
    
    show math(gold): 
        Same as show math, but the gold part.
    
    flaws:
        Find out why you shouldn't fully trust this.
    
    end:
        Goodbye!  
    """)


def starting_page():
    print("""
    *** EPIC DISCLAIMER ***
    This algorithm is FAR from perfect, specifics are written later. Just know that I do not want 
    to be held accountable for any actions you make because of the results. 
    
    Hello! This algorithm predicts (or tries to predict) when you'll get your new starr road brawler.
    
    If you encounter scary error messages, chances are you typed in invalid input. (rerun the code)
    Here are tips to increase your chance of valid inputs:
        *If it asks for a number, type only the number and no units
        *Copy & Paste is a great way to ensure the input is right
    
    I recommend using this right after you've done your daily quests or right before new daily quests spawn
    for the best accuracy.   
    
    Have fun! 
    (If no text cursor (flickering line) is here, click anywhere on the console and type.)
    (Press Enter after you finished typing.)                                                            
    """)


starting_page()

action_arr = [0, 0, 0]
pass_arr = [0,
            75, 75, 100, 150, 200, 300, 400, 400, 400, 400,
            400, 400, 400, 400, 400, 400, 400, 400, 400, 400,
            500, 500, 500, 500, 500, 500, 500, 500, 500, 500,
            500, 500, 500, 500, 500, 500, 500, 500, 500, 500,
            600, 600, 600, 600, 600, 600, 600, 600, 600, 600,
            600, 600, 600, 600, 600, 600, 600, 600, 600, 600,
            600, 600, 600, 600, 600, 600, 600, 600, 600, 600]
credit_pass_arr = [95,
                   0, 0, 0, 95, 0, 0, 0, 95, 0, 0,
                   0, 95, 0, 0, 0, 95, 0, 0, 0, 95,
                   0, 0, 0, 0, 95, 0, 0, 0, 0, 95,
                   0, 0, 95, 0, 0, 0, 0, 95, 0, 0,
                   0, 0, 95, 0, 0, 0, 0, 0, 95, 0,
                   0, 0, 0, 95, 0, 0, 0, 95, 0, 0,
                   0, 0, 95, 0, 0, 0, 0, 95, 0, 0]
gem_credit_pass_arr = [95,
                       0, 45, 0, 95, 45, 0, 0, 140, 0, 0,
                       0, 140, 0, 0, 45, 95, 0, 45, 0, 95,
                       0, 45, 0, 0, 140, 0, 0, 45, 0, 95,
                       0, 45, 95, 0, 0, 45, 0, 95, 0, 45,
                       0, 0, 95, 0, 0, 0, 45, 0, 95, 45,
                       0, 0, 0, 95, 0, 45, 0, 95, 0, 0,
                       0, 0, 95, 45, 0, 0, 0, 95, 0, 0]
gold_pass_arr = [0,
                 0, 0, 640, 0, 0, 640, 0, 0, 640, 0,
                 0, 0, 640, 0, 0, 0, 0, 640, 0, 0,
                 0, 0, 0, 640, 0, 0, 0, 640, 0, 0,
                 0, 640, 0, 0, 0, 0, 640, 0, 0, 0,
                 640, 0, 0, 0, 640, 0, 0, 640, 0, 0,
                 640, 0, 0, 0, 0, 640, 0, 0, 0, 640,
                 0, 0, 0, 0, 0, 0, 640, 0, 0, 0]
gem_gold_pass_arr = [0,
                     0, 0, 975, 0, 0, 975, 0, 0, 975, 0,
                     0, 0, 975, 0, 0, 335, 0, 640, 335, 0,
                     0, 0, 335, 640, 0, 335, 0, 640, 0, 0,
                     0, 640, 0, 335, 0, 0, 640, 335, 0, 0,
                     640, 335, 0, 0, 640, 335, 0, 975, 0, 0,
                     640, 335, 0, 0, 0, 640, 0, 0, 0, 975,
                     0, 335, 0, 0, 0, 0, 640, 335, 0, 0]
power_points_arr = [0, 0, 20, 50, 100, 180, 310, 520, 860, 1410, 2300, 3740]
gold_arr = [0, 0, 20, 55, 130, 270, 560, 1040, 1840, 3090, 4965, 7765]
job_done = False
total_done = False
all_gold_rewards = 0
this_tier_time = 0
math_process = ["_________________________________________________________________________________________________"]
math_process_2 = ["_________________________________________________________________________________________________"]
have_pass = input("Do you have the brawl pass this season?(Y/N) ")
input_right = False
while not input_right:
    if have_pass == "Y" or have_pass == "y":
        have_pass = True
        input_right = True
    elif have_pass == "N" or have_pass == "n":
        have_pass = False
        input_right = True
    else:
        have_pass = input("Y or N ")

day = 600 + 30 + 35 + 60 / 4
math_process.append("daily tokens = 600 + 30 + 35 + 60 / 4")
math_process.append(f"= {day}")
weekend_events = 50 + 500
math_process.append("weekend event tokens = 50 + 500")
math_process.append(f"= {weekend_events}")
if have_pass:
    math_process.append("You have the brawl pass.")
    week_seasonal = 250 * 4 + 500 * 4
    math_process.append("weekly seasonal quests = 250 * 4 + 500 * 4")
    math_process.append(f"= {week_seasonal}")
else:
    math_process.append("You don't have the brawl pass.")
    week_seasonal = 250 * 3 + 500 * 3
    math_process.append("weekly seasonal quests = 250 * 3 + 500 * 3")
    math_process.append(f"= {week_seasonal}")
one_week_tok = day * 7 + week_seasonal + weekend_events
math_process.append("one week total tokens = day * 7 + week seasonal + weekend events")
math_process.append(f"= {one_week_tok}")
one_day_tok = one_week_tok / 7
math_process.append("one day average token amount = one week total tokens / 7")
math_process.append(f"= {one_day_tok}")
math_process_2.append("one day average token amount = one week total tokens / 7")
math_process_2.append(f"= {one_day_tok}")
math_process_2.append(f"(one week total tokens is described clearly in 'show math')")
math_process_2.append("")

print("(The following question isn't that important, so don't stress over spelling it a certain way.)")
name = input("You're unlocking the brawler: ")

while True:
    try:
        start = int(input(f"Credit amount(bottom left of {name}'s face): "))
        if start < 3800:
            break
        else:
            print("Not possible(>=3800)")
    except ValueError:
        print("Only type the number.")
while True:
    try:
        end = int(input(f"Needed credit amount(bottom right of {name}'s face): "))
        if end <= 3800:
            break
        else:
            print("Not possible(>3800)")
    except ValueError:
        print("Only type the number.")
needed_credits = end - start
math_process.append(f"needed credits = {end} - {start}")
math_process.append(f"= {needed_credits}")
while True:
    try:
        cur_tok = int(input(f"Current token amount(left bottom corner): "))
        if cur_tok < 500:
            break
        else:
            print("Not possible(>=500)")
    except ValueError:
        print("Only type the number.")
math_process.append(f"current token amount = {cur_tok}")
math_process.append("")

while True:
    tier_now = input("Which tier are you at?(type 69+ if higher than 69) ")
    try:
        tier_now = int(tier_now)
        if tier_now <= 69:
            tier_now = str(tier_now)
            break
        else:
            print("Type 69+ if higher than 69.")
    except ValueError:
        if tier_now == "69+":
            break
        else:
            print("Type a number or 69+.")
while True:
    try:
        season_ends = int(input("How many days till season ends? (done daily quests -> round down, if not round up) "))
        if season_ends <= 70:
            break
        else:
            print("Not possible(>70)")
    except ValueError:
        print("Only type the number.")
math_process.append(f"Season ends in {season_ends} days")
available_tokens = season_ends * one_day_tok + cur_tok
math_process.append(f"Available tokens till season ends: {season_ends} * one day avg. token + {cur_tok}")
math_process.append(f"= {available_tokens}")
if tier_now != "69+":
    tier_now = int(tier_now) + 1
    math_process.append(f"tier -> {tier_now}")
    math_process_2.append(f"tier -> {tier_now}")
    tier_now_s = tier_now
    if have_pass:
        while True:
            available_tokens -= pass_arr[tier_now]
            math_process.append(f"available_tokens -> {available_tokens}")
            if available_tokens <= 0:
                math_process.append(f"available_tokens <= 0")
                break
            needed_credits -= gem_credit_pass_arr[tier_now]
            math_process.append(f"now needs {needed_credits} credits")
            all_gold_rewards += gem_gold_pass_arr[tier_now]
            math_process_2.append(f"all gold rewards -> {all_gold_rewards}")
            if needed_credits <= 0:
                math_process.append(f"needed credits <= 0")
                break
            tier_now += 1
            math_process.append(f"tier -> {tier_now}")
            math_process_2.append(f"tier -> {tier_now}")
            if tier_now > 70:
                math_process.append(f"got to end of pass")
                math_process_2.append(f"got to end of pass")
                break
    else:
        while True:
            available_tokens -= pass_arr[tier_now]
            math_process.append(f"available_tokens -> {available_tokens}")
            if available_tokens <= 0:
                math_process.append(f"available_tokens <= 0")
                break
            needed_credits -= credit_pass_arr[tier_now]
            math_process.append(f"now needs {needed_credits} credits")
            all_gold_rewards += gold_pass_arr[tier_now]
            math_process_2.append(f"all gold rewards -> {all_gold_rewards}")
            if needed_credits <= 0:
                math_process.append(f"needed credits <= 0")
                break
            tier_now += 1
            math_process.append(f"tier -> {tier_now}")
            math_process_2.append(f"tier -> {tier_now}")
            if tier_now > 70:
                math_process.append(f"got to end of pass")
                math_process_2.append(f"got to end of pass")
                break
    if needed_credits <= 0:
        print("_________________________________________________________________________________________________")
        print("Results:")
        print(f"You'll get {name} at tier {tier_now} this season")
        math_process.append(f"So you'll get {name} at tier {tier_now} this season")
        math_process.append(f"")
        math_process.append(f"Now we'll count how many tokens are needed.")
        k = tier_now_s
        needed_tier_tokens = 0
        math_process.append("needed tier tokens = 0 (for now)")
        math_process.append(f"starting tier = {k}")
        while k <= tier_now:
            needed_tier_tokens += pass_arr[k]
            math_process.append(f"needed tier tokens -> {needed_tier_tokens}")
            k += 1
            math_process.append(f"tier -> {k}")
        math_process.append("above end tier")
        time = (needed_tier_tokens - cur_tok) / one_day_tok
        math_process.append("time(days) = (needed tier tokens - current tokens) / one day average token amount")
        math_process.append(f"= {time}")
        time_r = math.ceil(time)
        math_process.append(f"round up -> {time_r}")
        print(f"It'll take around {time_r} days to get {name}")
        print(f"(which is around {today + datetime.timedelta(days=time_r)})")
        print("")
        math_process.append(f"So it'll take around {time_r} days to get {name}")
        print(f"You'll get {math.floor(all_gold_rewards)} coins along the way.")
        math_process_2.append(f"So you'll get {math.floor(all_gold_rewards)} coins along the way")
        job_done = True
if available_tokens <= 0:
    have_pass_2 = input("Would you get the brawl pass right away next season?(Y/N) ")
    input_right = False
    while not input_right:
        if have_pass_2 == "Y" or have_pass_2 == "y":
            have_pass_2 = True
            input_right = True
        elif have_pass_2 == "N" or have_pass_2 == "n":
            have_pass_2 = False
            input_right = True
        else:
            have_pass_2 = input("Y or N ")
    tier = 0
    if have_pass_2:
        math_process.append("You have the next brawl pass.")
        while True:
            needed_credits -= gem_credit_pass_arr[tier]
            math_process.append(f"needed credits -> {needed_credits}")
            all_gold_rewards += gem_gold_pass_arr[tier]
            math_process_2.append(f"all gold rewards -> {all_gold_rewards}")
            if needed_credits <= 0:
                math_process.append("needed credits <= 0")
                break
            tier += 1
            math_process.append(f"tier -> {tier}")
            math_process_2.append(f"tier -> {tier}")
            if tier > 70:
                math_process.append("end of next brawl pass(wow)")
                math_process_2.append("end of next brawl pass(wow)")
                math_process.append("")
                math_process_2.append("")
                break
    else:
        math_process.append("You don't have the next brawl pass.")
        while True:
            needed_credits -= credit_pass_arr[tier]
            math_process.append(f"needed credits -> {needed_credits}")
            all_gold_rewards += gold_pass_arr[tier]
            math_process_2.append(f"all gold rewards -> {all_gold_rewards}")
            if needed_credits <= 0:
                math_process.append("needed credits <= 0")
                break
            tier += 1
            math_process.append(f"tier -> {tier}")
            math_process_2.append(f"tier -> {tier}")
            if tier > 70:
                math_process.append("end of next brawl pass(wow)")
                math_process_2.append("end of next brawl pass(wow)")
                math_process.append("")
                math_process_2.append("")
                break
    if tier > 70:
        print("_________________________________________________________________________________________________")
        print("Results:")
        print(f"It'll be some time before you get {name}")
        print(f"(You'll get {name} next season tier 70+ or next next season)")
        print("The results will be less accurate.")
        math_process.append("I now assume you would get your brawler from the rewards at the end of the pass")
        math_process.append("Maybe that's wrong, but I think at this point you get why I don't keep going.")
        all_needed_tokens = 34500 + math.ceil(needed_credits / 25) * 500
        time = season_ends + all_needed_tokens / one_day_tok
        math_process.append(
            f"all needed tokens = 34500(tokens needed for tier 70)+ [round up({needed_credits}/25)]*500")
        math_process.append(f"= {all_needed_tokens}")
        math_process.append(f"time(days) = {season_ends} + all needed tokens/one day average token amount")
        math_process.append(f"= {season_ends} + {all_needed_tokens}/{one_day_tok}")
        math_process.append(f"= {time}")
        time_r = math.ceil(time)
        math_process.append(f"round up -> {time_r}")
        print(f"It'll take about {time_r} days to get {name}")
        print(f"(which is around {today + datetime.timedelta(days=time_r)})")
        print("")
        math_process.append(f"So it'll take about {time_r} days to get {name}")

        math_process_2.append(f"Daily gold reward gains: 15/4*{season_ends} = {15 / 4 * season_ends}")
        all_gold_rewards += 229 * math.ceil(needed_credits / 25)
        not_full_pp_gold_m = 84 * math.ceil(needed_credits / 25)
        math_process_2.append(
            f"end of next pass gold: (145+42*2) * {math.ceil(needed_credits / 25)}")
        math_process_2.append(f"= {229 * math.ceil(needed_credits / 25)}")
        math_process_2.append(
            f"all gold rewards -> {all_gold_rewards}")
        math_process_2.append(f"If the power point bank isn't full, next season rewards will be reduced by")
        math_process_2.append(f"42*2 * {math.ceil(needed_credits / 25)}")
        math_process_2.append(f"= {84 * math.ceil(needed_credits / 25)}")
        math_process_2.append(f"all gold reduction amount -> {not_full_pp_gold_m}")
        print(
            f"You'll get {math.floor(all_gold_rewards - not_full_pp_gold_m)} ~ {math.floor(all_gold_rewards)} coins along the way")
        print("(Min: Unlocked all end of pass rewards without a full power point bank. Max: Vice Versa)")
        math_process_2.append("")
        math_process_2.append(f"So you'll get about {all_gold_rewards} - {not_full_pp_gold_m}")
        math_process_2.append(f"= {all_gold_rewards - not_full_pp_gold_m}")
        math_process_2.append(
            f"-> {math.floor(all_gold_rewards - not_full_pp_gold_m)} without a full power point bank,")
        math_process_2.append(f"and about {all_gold_rewards}")
        math_process_2.append(f"-> {math.floor(all_gold_rewards)} with a full power point bank.")

    else:
        print("_________________________________________________________________________________________________")
        print("Results:")
        print(f"You'll get {name} at tier {tier} next season")
        math_process.append(f"So you'll get {name} at tier {tier} next season")
        math_process.append("")
        math_process.append(f"Now we'll count how many tokens are needed.")
        i = 0
        needed_tier_tokens = 0
        math_process.append("needed tier tokens = 0 (for now)")
        math_process.append(f"starting tier = {i}")
        while i <= tier:
            needed_tier_tokens += pass_arr[i]
            math_process.append(f"needed tier tokens -> {needed_tier_tokens}")
            i += 1
            math_process.append(f"tier -> {i}")
        math_process.append("above end tier")
        time = season_ends + needed_tier_tokens / one_day_tok
        math_process.append(f"time(days) = {season_ends} + needed tier tokens / one day average token amount")
        math_process.append(f"= {time}")
        time_r = math.ceil(time)
        math_process.append(f"round up -> {time_r}")
        print(f"It'll take {time_r} days to get {name}")
        print(f"(which is around {today + datetime.timedelta(days=time_r)})")
        print("")
        math_process.append(f"So it'll take {time_r} days to get {name}")
        print(f"You'll get {math.floor(all_gold_rewards)} coins along the way.")
        math_process_2.append(f"So you'll get {math.floor(all_gold_rewards)} coins along the way")


elif not job_done:
    ori_season_ends = season_ends
    season_ends = math.floor(available_tokens/one_day_tok)
    this_tier_time = ori_season_ends - season_ends
    math_process.append("season now ends in")
    math_process.append("[round down(available tokens/one day tok)] days")
    math_process.append(f"= {season_ends}")
    math_process.append(f"We've past {this_tier_time} days")
    cur_tok = available_tokens % one_day_tok
    math_process.append(f"gotten {available_tokens % one_day_tok} extra tokens -> new current tokens")
    math_process.append(f"")
    time = (math.ceil(needed_credits/25)*500 - cur_tok) / one_day_tok
    math_process.append(f"It takes {needed_credits}/25 -> at least {math.ceil(needed_credits/25)} end rewards.")
    math_process.append(f"-> at least {math.ceil(needed_credits/25)*500} tokens")
    math_process.append(f"time(days) = ({math.ceil(needed_credits/25)*500}-{cur_tok})/ one day token reward")
    math_process.append(f"= {time}")
    time_r = math.ceil(time)
    math_process.append(f"round up -> {time_r}")

    if time_r > season_ends:
        math_process.append(f"BUT because {time_r} > {season_ends}, so more math")
        have_pass_2 = input("Would you get the brawl pass right away next season?(Y/N) ")
        input_right = False
        while not input_right:
            if have_pass_2 == "Y" or have_pass_2 == "y":
                have_pass_2 = True
                input_right = True
            elif have_pass_2 == "N" or have_pass_2 == "n":
                have_pass_2 = False
                input_right = True
            else:
                have_pass_2 = input("Y or N ")
        needed_credits_2 = needed_credits - math.floor((one_day_tok * season_ends + cur_tok)/500)*25
        math_process.append(
            f"end reward(packs) = round down[(one day token rewards * {season_ends} + current tokens)/500]")
        math_process.append(f"= {math.floor((one_day_tok * season_ends + cur_tok)/500)}")
        math_process_2.append(
            f"end reward(packs) = round down[(one day token rewards * {season_ends} + current tokens)/500]")
        math_process_2.append(f"= {math.floor((one_day_tok * season_ends + cur_tok) / 500)}")
        math_process.append(f"earned credits = {math.floor((one_day_tok * season_ends + cur_tok) / 500)*25}")
        math_process.append(
            f"needed credits = {needed_credits} - {math.floor((one_day_tok * season_ends + cur_tok)/500)*25}")
        math_process.append(f"= {needed_credits_2}")
        all_gold_rewards += 15/4 * season_ends
        math_process_2.append(f"Daily gold reward gains: 15/4*{season_ends} = {15/4 * season_ends}")
        all_gold_rewards += 229 * math.floor((one_day_tok * season_ends + cur_tok)/500)
        not_full_pp_gold_m = 84 * math.floor((one_day_tok * season_ends + cur_tok)/500)
        math_process_2.append(
            f"end of pass gold: (145+42*2) * {math.floor((one_day_tok * season_ends + cur_tok) / 500)}")
        math_process_2.append(f"= {229 * math.floor((one_day_tok * season_ends + cur_tok)/500)}")
        math_process_2.append("")
        math_process_2.append(f"If the power point bank isn't full, gold rewards will be reduced by")
        math_process_2.append(f"42*2 * {math.floor((one_day_tok * season_ends + cur_tok) / 500)}")
        math_process_2.append(f"= {not_full_pp_gold_m}")
        math_process_2.append(f"(We'll use this later)")
        math_process_2.append("")
        math_process_2.append(f"all gold rewards -> {all_gold_rewards}")

        tier = 0
        math_process.append("")
        math_process.append("We start on tier 0")
        math_process_2.append(f"We start on tier 0")
        if have_pass_2:
            math_process.append("You have the next brawl pass.")
            math_process_2.append("You have the next brawl pass.")
            while True:
                needed_credits_2 -= gem_credit_pass_arr[tier]
                math_process.append(f"needed credits -> {needed_credits_2}")
                all_gold_rewards += gem_gold_pass_arr[tier]
                math_process_2.append(f"all gold rewards -> {all_gold_rewards}")
                if needed_credits_2 <= 0:
                    math_process.append("needed credits <= 0")
                    break
                tier += 1
                math_process.append(f"tier -> {tier}")
                math_process_2.append(f"tier -> {tier}")
                if tier > 70:
                    math_process.append("end of next brawl pass(wow)")
                    math_process_2.append("end of next brawl pass(wow)")
                    math_process.append("")
                    math_process_2.append("")
                    break
        else:
            math_process.append("You don't have the next brawl pass.")
            math_process_2.append("You don't have the next brawl pass.")
            while True:
                needed_credits_2 -= credit_pass_arr[tier]
                math_process.append(f"needed credits -> {needed_credits_2}")
                all_gold_rewards += gold_pass_arr[tier]
                math_process_2.append(f"all gold rewards -> {all_gold_rewards}")
                if needed_credits_2 <= 0:
                    math_process.append("needed credits <= 0")
                    break
                tier += 1
                math_process.append(f"tier -> {tier}")
                math_process_2.append(f"tier -> {tier}")
                if tier > 70:
                    math_process.append("end of next brawl pass(wow)")
                    math_process_2.append("end of next brawl pass(wow)")
                    math_process.append("")
                    math_process_2.append("")
                    break
        if tier > 70:
            print("_________________________________________________________________________________________________")
            print("Results:")
            print(f"It'll be some time before you get {name}")
            print(f"(You'll get {name} next season tier 70+ or next next season)")
            print("The results will be less accurate.")
            math_process.append("I now assume you would get your brawler from the rewards at the end of the pass")
            math_process.append("Maybe that's wrong, but I think at this point you get why I don't keep going.")
            all_needed_tokens = 34500 + math.ceil(needed_credits_2/25)*500
            time = ori_season_ends + all_needed_tokens / one_day_tok
            math_process.append(
                f"all needed tokens = 34500(tokens needed for tier 70)+ [round up({needed_credits_2}/25)]*500")
            math_process.append(f"= {all_needed_tokens}")
            math_process.append(f"time(days) = {ori_season_ends} + all needed tokens/one day average token amount")
            math_process.append(f"= {ori_season_ends} + {all_needed_tokens}/{one_day_tok}")
            math_process.append(f"= {time}")
            time_r = math.ceil(time)
            math_process.append(f"round up -> {time_r}")
            print(f"It'll take about {time_r} days to get {name}")
            print(f"(which is around {today + datetime.timedelta(days=time_r)})")
            print("")
            math_process.append(f"So it'll take about {time_r} days to get {name}")
            all_gold_rewards += 15 / 4 * (time_r-ori_season_ends)
            math_process_2.append(
                f"Daily gold reward gains: 15/4*({time_r}-{ori_season_ends}) = {15/4*(time_r-ori_season_ends)}")
            all_gold_rewards += 229 * math.ceil(needed_credits_2/25)
            not_full_pp_gold_m += 84 * math.ceil(needed_credits_2/25)
            math_process_2.append(
                f"end of next pass gold: (145+42*2) * {math.ceil(needed_credits_2/25)}")
            math_process_2.append(f"= {229 * math.ceil(needed_credits_2/25)}")
            math_process_2.append(
                f"all gold rewards -> {all_gold_rewards}")
            math_process_2.append(f"If the power point bank isn't full, next season rewards will be reduced by")
            math_process_2.append(f"42*2 * {math.ceil(needed_credits_2/25)}")
            math_process_2.append(f"= {84 * math.ceil(needed_credits_2/25)}")
            math_process_2.append(f"all gold reduction amount -> {not_full_pp_gold_m}")
            print(f"You'll get {math.floor(all_gold_rewards-not_full_pp_gold_m)} ~ {math.floor(all_gold_rewards)} coins along the way")
            print("(Min: Unlocked all end of pass rewards without a full power point bank. Max: Vice Versa)")
            math_process_2.append("")
            math_process_2.append(f"So you'll get about {all_gold_rewards} - {not_full_pp_gold_m}")
            math_process_2.append(f"= {all_gold_rewards-not_full_pp_gold_m}")
            math_process_2.append(f"-> {math.floor(all_gold_rewards-not_full_pp_gold_m)} without a full power point bank,")
            math_process_2.append(f"and about {all_gold_rewards}")
            math_process_2.append(f"-> {math.floor(all_gold_rewards)} with a full power point bank.")

        else:
            print("_________________________________________________________________________________________________")
            print("Results:")
            print(f"You'll get {name} at tier {tier} next season")
            math_process.append(f"So you'll get {name} at tier {tier} next season")
            math_process.append("")
            math_process.append(f"Now we'll count how many tokens are needed.")
            i = 0
            needed_tier_tokens = 0
            math_process.append("needed tier tokens = 0 (for now)")
            math_process.append(f"starting tier = {i}")
            while i <= tier:
                needed_tier_tokens += pass_arr[i]
                math_process.append(f"needed tier tokens -> {needed_tier_tokens}")
                i += 1
                math_process.append(f"tier -> {i}")
            math_process.append("above end tier")
            time = ori_season_ends + needed_tier_tokens / one_day_tok
            math_process.append(f"time(days) = {ori_season_ends} + needed tier tokens / one day average token amount")
            math_process.append(f"= {time}")
            time_r = math.ceil(time)
            math_process.append(f"round up -> {time_r}")
            print(f"It'll take {time_r} days to get {name}")
            print(f"(which is around {today + datetime.timedelta(days=time_r)})")
            print("")
            math_process.append(f"So it'll take {time_r} days to get {name}")
            print(
                f"You'll get {math.floor(all_gold_rewards - not_full_pp_gold_m)} ~ {math.floor(all_gold_rewards)} coins along the way")
            print("(Min: Unlocked all end of pass rewards without a full power point bank. Max: Vice Versa)")
            math_process_2.append("")
            math_process_2.append(f"So you'll get about {all_gold_rewards} - {not_full_pp_gold_m}")
            math_process_2.append(f"= {all_gold_rewards - not_full_pp_gold_m}")
            math_process_2.append(
                f"-> {math.floor(all_gold_rewards - not_full_pp_gold_m)} without a full power point bank,")
            math_process_2.append(f"and about {all_gold_rewards}")
            math_process_2.append(f"-> {math.floor(all_gold_rewards)} with a full power point bank.")

    else:
        print("_________________________________________________________________________________________________")
        print("Results:")
        print(f"It'll take around {time_r + this_tier_time} days to get {name}")
        print(f"(which is around {today + datetime.timedelta(days=time_r + this_tier_time)})")
        print(f"")
        math_process.append(f"{this_tier_time} + {time_r} = {time_r + this_tier_time}")
        math_process.append(f"We'll get {name} this season")
        math_process.append(f"It'll take around {time_r + this_tier_time} days to get {name}")
        all_gold_rewards += 229 * math.ceil(needed_credits/25)
        not_full_pp_gold_m = 84 * math.ceil(needed_credits/25)
        math_process_2.append(
            f"end of next pass gold: (145+42*2) * {math.ceil(needed_credits / 25)}")
        math_process_2.append(f"= {229 * math.ceil(needed_credits / 25)}")
        math_process_2.append(f"If the power point bank isn't full, next season rewards will be reduced by")
        math_process_2.append(f"42*2 * {math.ceil(needed_credits / 25)}")
        math_process_2.append(f"= {84 * math.ceil(needed_credits / 25)}")
        math_process_2.append("")
        print(
                f"You'll get {math.floor(all_gold_rewards - not_full_pp_gold_m)} ~ {math.floor(all_gold_rewards)} coins along the way")
        print("(Min: Unlocked all end of pass rewards without a full power point bank. Max: Vice Versa)")
        math_process_2.append("")
        math_process_2.append(f"So you'll get about {all_gold_rewards} - {not_full_pp_gold_m}")
        math_process_2.append(f"= {all_gold_rewards - not_full_pp_gold_m}")
        math_process_2.append(
            f"-> {math.floor(all_gold_rewards - not_full_pp_gold_m)} without a full power point bank,")
        math_process_2.append(f"and about {all_gold_rewards}")
        math_process_2.append(f"-> {math.floor(all_gold_rewards)} with a full power point bank.")

print("_________________________________________________________________________________________________")
first_look = True
while True:
    if first_look:
        first_look_page()
        first_look = False
    else:
        if action_arr[0] == 0:
            print("show math")
        if action_arr[1] == 0:
            print("show math(gold)")
        if action_arr[2] == 0:
            print("flaws")
        print("end")
    print("")
    user_action = input("Action: ")
    if user_action == "show math" and action_arr[0] == 0:
        for thing in math_process:
            print(thing)
        action_arr[0] = 1
    elif user_action == "show math(gold)" and action_arr[1] == 0:
        for thing in math_process_2:
            print(thing)
        action_arr[1] = 1
    elif user_action == "flaws" and action_arr[2] == 0:
        flaws()
        action_arr[2] = 1
    elif user_action == "end":
        print("goodbye :)")
        break
    else:
        print("Invalid input. Try copying & pasting one of the actions")
    print("_________________________________________________________________________________________________")
    print("What now?")
# Out:
#     *** EPIC DISCLAIMER ***
#     This algorithm is FAR from perfect, specifics are written later. Just know that I do not want
#     to be held accountable for any actions you make because of the results.
#
#     Hello! This algorithm predicts (or tries to predict) when you'll get your new starr road brawler.
#
#     If you encounter scary error messages, chances are you typed in invalid input. (rerun the code)
#     Here are tips to increase your chance of valid inputs:
#         *If it asks for a number, type only the number and no units
#         *Copy & Paste is a great way to ensure the input is right
#
#     I recommend using this right after you've done your daily quests or right before new daily quests spawn
#     for the best accuracy.
#
#     Have fun!
#     (If no text cursor (flickering line) is here, click anywhere on the console and type.)
#     (Press Enter after you finished typing.)
# Do you have the brawl pass this season?(Y/N)  Y
# ...
